# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/drive/My Drive/csvs/Corona.csv')

# %%
pd.options.display.max_rows = 10
df
# Out:
#      Unnamed: 0 Province/State  ... Latitude Longitude
# 0             0          Hubei  ...  30.9756  112.2707
# 1             1            NaN  ...  41.8719   12.5674
# 2             2            NaN  ...  32.4279   53.6880
# 3             3            NaN  ...  40.4637   -3.7492
# 4             4            NaN  ...  51.1657   10.4515
# ..          ...            ...  ...      ...       ...
# 271         271            NaN  ...  49.4500   -2.5800
# 272         272            NaN  ...  49.1900   -2.1100
# 273         273            NaN  ...  18.2000  -66.5000
# 274         274            NaN  ...  -1.4400   15.5560
# 275         275            NaN  ...  31.9522   35.2332
#
# [276 rows x 9 columns]

# %%
#Question One - By default shows first 5
df.head()
# Out:
#    Unnamed: 0 Province/State Country/Region  ... Recovered  Latitude  Longitude
# 0           0          Hubei          China  ...     56003   30.9756   112.2707
# 1           1            NaN          Italy  ...      2941   41.8719    12.5674
# 2           2            NaN           Iran  ...      5389   32.4279    53.6880
# 3           3            NaN          Spain  ...      1028   40.4637    -3.7492
# 4           4            NaN        Germany  ...        67   51.1657    10.4515
#
# [5 rows x 9 columns]

# %%
#Question one
df.isnull().sum()
# 150 records out of 276 rows are having Province/State is NULL
# Out:
# Unnamed: 0          0
# Province/State    150
# Country/Region      0
# Last Update         0
# Confirmed           0
# Deaths              0
# Recovered           0
# Latitude            0
# Longitude           0
# dtype: int64

# %%
# Question two
# Calculating the active cases based on the country
df['Active Cases'] = df['Confirmed']-df['Recovered']-df['Deaths']
df
# Out:
#      Unnamed: 0 Province/State  ... Longitude Active Cases
# 0             0          Hubei  ...  112.2707         8685
# 1             1            NaN  ...   12.5674        26062
# 2             2            NaN  ...   53.6880         9792
# 3             3            NaN  ...   -3.7492        10187
# 4             4            NaN  ...   10.4515         9166
# ..          ...            ...  ...       ...          ...
# 271         271            NaN  ...   -2.5800            0
# 272         272            NaN  ...   -2.1100            0
# 273         273            NaN  ...  -66.5000            0
# 274         274            NaN  ...   15.5560            0
# 275         275            NaN  ...   35.2332            0
#
# [276 rows x 10 columns]

# %%
#Question Three
count_series = df.groupby(['Province/State','Country/Region', 'Last Update']).size()
count_series
# Out:
# Province/State                Country/Region                    Last Update
# 0                             Afghanistan                       2020-03-17T11:53:10    1
#                               Albania                           2020-03-17T15:53:12    1
#                               Algeria                           2020-03-17T03:13:15    1
#                               Andorra                           2020-03-17T20:53:02    1
#                               Antigua and Barbuda               2020-03-15T18:20:19    1
#                               Argentina                         2020-03-17T15:53:12    1
#                               Armenia                           2020-03-17T19:33:02    1
#                               Aruba                             2020-03-17T12:33:07    1
#                               Austria                           2020-03-17T15:33:06    1
#                               Azerbaijan                        2020-03-17T11:53:10    1
# ...

# %% [markdown]
# # As we can see that, the combination of all 3 state, country & last update is just 1, that implies that all data is unique

# %%
#Question Three
#Finding unique countries
unique_countries = df["Country/Region"].nunique()
print(unique_countries)
# Out:
# 159

# %%
#Question Three
#Grouping the countries
pd.options.display.max_rows = 10
DataFrameCountryWise = df[['Country/Region','Confirmed','Recovered','Deaths','Active Cases']].groupby(by=['Country/Region']).sum()
DataFrameCountryWise
# Out:
#                                 Confirmed  Recovered  Deaths  Active Cases
# Country/Region
# Afghanistan                            22          1       0            21
# Albania                                55          0       1            54
# Algeria                                60         12       4            44
# Andorra                                39          1       0            38
# Antigua and Barbuda                     1          0       0             1
# ...                                   ...        ...     ...           ...
# Uruguay                                29          0       0            29
# Uzbekistan                             10          0       0            10
# Venezuela                              33          0       0            33
# Vietnam                                66         16       0            50
# occupied Palestinian territory          0          0       0             0
#
# [159 rows x 4 columns]

# %%
#Question Four
DataFrameCountryWiseStateWise = df[['Country/Region','Province/State','Confirmed','Recovered','Deaths','Active Cases']]
pd.options.display.max_rows = 10
DataFrameCountryWiseStateWise
# Out:
#                      Country/Region Province/State  ...  Deaths  Active Cases
# 0                             China          Hubei  ...    3111          8685
# 1                             Italy            NaN  ...    2503         26062
# 2                              Iran            NaN  ...     988          9792
# 3                             Spain            NaN  ...     533         10187
# 4                           Germany            NaN  ...      24          9166
# ..                              ...            ...  ...     ...           ...
# 271                        Guernsey            NaN  ...       0             0
# 272                          Jersey            NaN  ...       0             0
# 273                     Puerto Rico            NaN  ...       0             0
# 274           Republic of the Congo            NaN  ...       0             0
# 275  occupied Palestinian territory            NaN  ...       0             0
#
# [276 rows x 6 columns]

# %%
#Question Fifth
#Selecting data which is just from China
chinaData = df.loc[df['Country/Region'] == "China"]
lengthOfChineaseCases = len(chinaData.index)
pd.options.display.max_rows = lengthOfChineaseCases
chinaData
# Out:
#      Unnamed: 0  Province/State  ... Longitude Active Cases
# 0             0           Hubei  ...  112.2707         8685
# 12           12       Guangdong  ...  113.4244           49
# 14           14           Henan  ...  113.6140            1
# 16           16        Zhejiang  ...  120.0934           15
# 19           19           Hunan  ...  111.7088            0
# 20           20           Anhui  ...  117.2264            0
# 22           22         Jiangxi  ...  115.7221            0
# 24           24        Shandong  ...  118.1498            8
# 28           28         Jiangsu  ...  119.4550            0
# 29           29       Chongqing  ...  107.8740            0
# 30           30         Sichuan  ...  102.7103           17
# 31           31    Heilongjiang  ...  127.7615           13
# 32           32         Beijing  ...  116.4142           79
# 37           37        Shanghai  ...  121.4491           30
# 41           41           Hebei  ...  114.5149            2
# ...

# %%
#Question Fifth
print(lengthOfChineaseCases)
# Out:
# 33

# %%
#Question Six
df.head(10)
# Out:
#    Unnamed: 0  Province/State  ... Longitude Active Cases
# 0           0           Hubei  ...  112.2707         8685
# 1           1             NaN  ...   12.5674        26062
# 2           2             NaN  ...   53.6880         9792
# 3           3             NaN  ...   -3.7492        10187
# 4           4             NaN  ...   10.4515         9166
# 5           5             NaN  ...  127.7669         6832
# 6           6          France  ...    2.2137         7492
# 7           7             NaN  ...    8.2275         2669
# 8           8  United Kingdom  ...   -3.4360         1843
# 9           9        New York  ...  -74.9481         1693
#
# [10 rows x 10 columns]

# %%
#Question Seven
recoveredData = DataFrameCountryWise.loc[DataFrameCountryWise['Active Cases'] == 0]
recoveredData
# Out:
#                                 Confirmed  Recovered  Deaths  Active Cases
# Country/Region
# Guernsey                                0          0       0             0
# Jersey                                  0          0       0             0
# Nepal                                   1          1       0             0
# Puerto Rico                             0          0       0             0
# Republic of the Congo                   0          0       0             0
# Sudan                                   1          0       1             0
# occupied Palestinian territory          0          0       0             0

# %%
#Question Seven
lengthOfrecoveredData = len(recoveredData.index)
print(lengthOfrecoveredData)
# Out:
# 7

# %%
df.sort_values(by=['Country/Region','Province/State','Last Update'],ascending=[False,False, False])
# Out:
#      Unnamed: 0                Province/State  \
# 275  275         0
# 110  110         0
# 143  143         0
# 191  191         0
# 149  149         0
# 8    8           United Kingdom
# 232  232         Gibraltar
# 212  212         Channel Islands
# 269  269         Cayman Islands
# 88   88          0
# 177  177         0
# 187  187         Wyoming
# 102  102         Wisconsin
# 268  268         West Virginia
# 18   18          Washington
# 108  108         Virginia
# 240  240         Virgin Islands
# 182  182         Vermont
# 124  124         Utah
# 85   85          Texas
# 100  100         Tennessee
# 186  186         South Dakota
# 130  130         South Carolina
# 161  161         Rhode Island
# 218  218         Puerto Rico
# 84   84          Pennsylvania
# 109  109         Oregon
# 170  170         Oklahoma
# 107  107         Ohio
# 231  231         North Dakota
# 115  115         North Carolina
# 9    9           New York
# 160  160         New Mexico
# ...
